# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread(r"C:\MY backUp 2024\MyAlbums\Bro\IMG-20240210-WA0054.jpg")

# %%
plt.imshow(img1)

# %%
rgb_img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# Display the image in RGB format
plt.imshow(rgb_img)
