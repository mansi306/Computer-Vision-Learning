# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"C:\MY backUp 2024\MyAlbums\Bro\IMG-20240210-WA0064.jpg")

# %%
img.shape
# Out:
# (1280, 963, 3)

# %%
plt.imshow(img)

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image in RGB format
plt.imshow(rgb_img)

# %%
pic = rgb_img.copy()

# %%
pic1= cv2.resize(pic,(500,1000))
plt.imshow(pic1)

# %%
new_pic = cv2.resize(pic,(0,0),pic,0.5,0.5)
plt.imshow(new_pic)

# %%
new_pic.shape
# Out:
# (640, 482, 3)

# %%
pic_flip= cv2.flip(new_pic,0)
plt.imshow(pic_flip)

# %%
pic_flip= cv2.flip(new_pic,1)
plt.imshow(pic_flip)

# %%
pic_flip= cv2.flip(new_pic,-1)
plt.imshow(pic_flip)
